# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE

# %%
data = pd.read_csv('/Volumes/Database/Research/C7 Multivariate analysis/MRI-ESM2-0_diag_2014(0319).csv')

# %%
country = pd.read_csv('/Users/csuen/Desktop/PhD/Maps/country_province_state_2*2.csv')
data = data.merge(country, how = 'left', left_on = ['longitude','latitude'], right_on = ['longitude','latitude'])
data = data.drop(['province','state'], axis=1)

# %% [markdown]
# ### First, converse the concentrations in ppb to molecules cm${^{-3}}$

# %%
data['o3_mole'] = data['o3']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['no_mole'] = data['no']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['no2_mole'] = data['no2']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['oh_mole'] = data['oh']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['h2o_mole'] = data['h2o']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['hno3_mole'] = data['hno3']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)
data['pan_mole'] = data['pan']*1.01325*10**5/data['tas']*7.243*10**7*(10**9)

data['k_ho2_ho2'] = 2.2*10**(-13)*np.exp(600/data['tas'])
data['k_oh_no2'] = 6.5*10**(-11)
data['k_o1d_h2o'] = 2.14*10**(-10)

data['o3prod_mole'] = data['o3prod']*6.022*10**17
data['o3loss_mole'] = data['o3loss']*6.022*10**17

data['lossch4_mole'] = data['lossch4']*6.022*10**17
data['k_ch3o2_ch3o2'] = 1.03*10**(-13)*np.exp(365/data['tas'])

# %%
data['a'] = 2*data['k_ch3o2_ch3o2']
data['b'] = data['k_no_ch3o2']*data['no_mole']
data['c'] = -data['lossch4_mole']

# %%
data['ch3o2_mole'] = (-data['b'] + np.sqrt(data['b']**2 - 4*data['a']*data['c']))/(2*data['a'])

# %%
data['ratio_ch3o2_oh'] = data['ch3o2_mole']/data['oh_mole']
data['ratio_ch3o2_oh'].describe()
# Out:
# count    972000.000000
# mean        783.165131
# std        2264.665022
# min           0.012404
# 25%          33.480962
# 50%         124.989232
# 75%         360.933056
# max       23850.704656
# Name: ratio_ch3o2_oh, dtype: float64

# %%
data['P2'] = data['k_no_ch3o2']*data['no_mole']*data['ch3o2_mole']
data['P2_frac'] = data['P2']/data['o3prod_mole']
data['P2_frac'].describe()
# Out:
# count    972000.000000
# mean          0.358578
# std           0.293137
# min           0.001940
# 25%           0.108217
# 50%           0.297502
# 75%           0.574962
# max          12.524778
# Name: P2_frac, dtype: float64

# %%
data['loc'] = data['longitude']*1000 + data['latitude']
data_land = data
#data_land = data_land[data_land['latitude'] >= -60]
#data_land = data_land[data_land['P2_frac'] <1]
data_mean = data_land.groupby(['loc']).mean()

cm = plt.cm.get_cmap('Blues')
x = data_mean['longitude']
y = data_mean['latitude']
z = data_mean['P2_frac']
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=0.5, s=3, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)
plt.show()

# %%
data_mean['P2_frac'].describe()
# Out:
# count    16200.000000
# mean         0.358578
# std          0.256576
# min          0.002382
# 25%          0.112203
# 50%          0.346859
# 75%          0.606369
# max          0.959819
# Name: P2_frac, dtype: float64

# %%
data['loc'] = data['longitude']*1000 + data['latitude']
data_land = data
#data_land = data_land[data_land['latitude'] >= -60]
data_mean = data_land.groupby(['loc']).mean()

cm = plt.cm.get_cmap('Reds')
x = data_mean['longitude']
y = data_mean['latitude']
z = data_mean['ch3o2_mole']*10**(-8)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=1, s=3, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)
plt.show()

# %%
data['P3'] = data['o3prod_mole'] - data['P1'] - data['P2']
data['P3_frac'] = data['P3']/data['o3prod_mole']
data['P3_frac'].describe()
# Out:
# count    972000.000000
# mean          0.334304
# std           0.346104
# min         -13.053668
# 25%           0.085219
# 50%           0.336948
# 75%           0.547347
# max           0.994637
# Name: P3_frac, dtype: float64

# %%
data['P5'] = data['k_o3_oh']*data['o3_mole']*data['oh_mole']
data['P5_frac'] = data['P5']/data['o3loss_mole']

# %%
data['P6'] = data['k_o3_ho2']*data['o3_mole']*data['ho2_mole']
data['P6_frac'] = data['P6']/data['o3loss_mole']

# %%
data['ratio_P1_P2'] = data['P1']/data['P2']
data['ratio_P1_P2'].describe()
# Out:
# count    972000.000000
# mean          1.896978
# std           2.046132
# min           0.015406
# 25%           0.575077
# 50%           1.226490
# 75%           2.703125
# max          64.508160
# Name: ratio_P1_P2, dtype: float64

# %%
data['ratio_P5_P6'] = data['P5']/data['P6']
data['ratio_P5_P6'].describe()
# Out:
# count    972000.000000
# mean          0.624917
# std           1.517090
# min           0.013332
# 25%           0.130603
# 50%           0.223657
# 75%           0.446289
# max          66.783031
# Name: ratio_P5_P6, dtype: float64

# %%
data = data.drop(['a','b','c','country_y'], axis=1)
data = data.rename(columns={'country_x':'country'})
data
# Out:
#         longitude  latitude     t     loc            o3        o3prod  \
# 0             1.0     -89.0   1.0   911.0  1.754211e-08  2.336547e-14
# 1             3.0     -89.0   1.0  2911.0  1.751341e-08  2.332420e-14
# 2             5.0     -89.0   1.0  4911.0  1.744699e-08  2.322402e-14
# 3             7.0     -89.0   1.0  6911.0  1.744699e-08  2.322402e-14
# 4             9.0     -89.0   1.0  8911.0  1.745826e-08  2.328491e-14
# ...           ...       ...   ...     ...           ...           ...
# 971995       -9.0      89.0  60.0 -8911.0  2.287199e-08  7.559570e-16
# 971996       -7.0      89.0  60.0 -6911.0  2.284715e-08  1.474946e-16
# 971997       -5.0      89.0  60.0 -4911.0  2.284715e-08  1.474946e-16
# 971998       -3.0      89.0  60.0 -2911.0  2.283424e-08  3.365895e-16
# 971999       -1.0      89.0  60.0  -911.0  2.281498e-08  7.303474e-16
#
#               o3loss        eminox        emivoc        tas  ...           P2  \
# 0       4.840957e-14  0.000000e+00  0.000000e+00  245.63487  ...  9614.727767
# 1       4.801625e-14  0.000000e+00  0.000000e+00  245.64409  ...  9538.925991
# 2       4.737500e-14  0.000000e+00  0.000000e+00  245.48904  ...  9422.781522
# 3       4.737500e-14  0.000000e+00  0.000000e+00  245.48055  ...  9422.862857
# 4       4.718132e-14  0.000000e+00  0.000000e+00  245.57079  ...  9382.193380
# ...              ...           ...           ...        ...  ...          ...
# 971995  1.561717e-15  7.690745e-14  1.949230e-16  251.85805  ...    82.557861
# 971996  1.534075e-15  4.297552e-15  1.089221e-17  251.88918  ...    56.486015
# 971997  1.534075e-15  4.297552e-15  1.089221e-17  251.92060  ...    56.482270
# 971998  1.605734e-15  1.650221e-14  4.182508e-17  251.93549  ...    74.320330
# 971999  1.560100e-15  7.247755e-14  1.836954e-16  251.96606  ...    81.690951
#
#          P2_frac           P3   P3_frac           P5   P5_frac            P6  \
# 0       0.683316 -5476.493429 -0.389213  4099.309647  0.140617  22606.257034
# 1       0.679128 -5425.694916 -0.386285  4091.226512  0.141490  22504.564596
# 2       0.673753 -5343.777582 -0.382094  4050.976791  0.141994  22270.372510
# 3       0.673759 -5344.384612 -0.382137  4050.719770  0.141985  22269.363951
# 4       0.669097 -5303.571028 -0.378227  4069.849927  0.143241  22263.044757
# ...          ...          ...       ...          ...       ...           ...
# 971995  0.181351   251.565200  0.552602    18.261624  0.019418    458.090100
# 971996  0.635951    24.703726  0.278129    15.499220  0.016777    489.596822
# 971997  0.635909    24.710119  0.278200    15.502567  0.016781    489.603414
# 971998  0.366662    98.286116  0.484899    16.910557  0.017488    510.962620
# 971999  0.185739   244.011025  0.554804    17.996422  0.019155    456.879220
#
#          P6_frac  ratio_P1_P2  ratio_P5_P6
# 0       0.775455     1.033046     0.181335
# 1       0.778290     1.041271     0.181795
# 2       0.780616     1.051335     0.181900
# 3       0.780581     1.051382     0.181897
# 4       0.783563     1.059832     0.182807
# ...          ...          ...          ...
# 971995  0.487088     1.467023     0.039865
# 971996  0.529970     0.135105     0.031657
# 971997  0.529977     0.135067     0.031664
# 971998  0.528414     0.404839     0.033095
# 971999  0.486304     1.396889     0.039390
#
# [972000 rows x 70 columns]

# %%
data.to_csv('/Volumes/Database/Research/C7 Multivariate analysis/MRI-ESM2-0_diag_2014(0320).csv', index = False)

# %%
data_land = data.dropna()
ratio_P1_P2 = data_land['ratio_P1_P2'].median()
ratio_P5_P6 = data_land['ratio_P5_P6'].median()
P1_frac = data_land['P1_frac'].mean()
P2_frac = data_land['P2_frac'].mean()
P3_frac = data_land['P3_frac'].mean()
P5_frac = data_land['P5_frac'].mean()
P6_frac = data_land['P6_frac'].mean()
ratio_ho2_oh = data_land['ratio_ho2_oh'].median()
ratio_ch3o2_oh = data_land['ratio_ch3o2_oh'].median()

# %%
print("P1 fraction:    "+str(np.round(P1_frac,2)))
print("P2 fraction:    "+str(np.round(P2_frac,2)))
print("P3 fraction:    "+str(np.round(P3_frac,2)))
print("P5 fraction:    "+str(np.round(P5_frac,2)))
print("P6 fraction:    "+str(np.round(P6_frac,2)))
print("P1:P2 ratio:    "+str(np.round(ratio_P1_P2,2)))
print("P5:P6 ratio:    "+str(np.round(ratio_P5_P6,2)))
print("HO\u2082:OH ratio:   "+str(np.round(ratio_ho2_oh,1)))
print("CH\u2083O\u2082:OH ratio: "+str(np.round(ratio_ch3o2_oh,1)))
# Out:
# P1 fraction:    0.25
# P2 fraction:    0.25
# P3 fraction:    0.5
# P5 fraction:    0.14
# P6 fraction:    0.41
# P1:P2 ratio:    2.57
# P5:P6 ratio:    0.4
# HO₂:OH ratio:   85.0
# CH₃O₂:OH ratio: 30.3
