# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import iris
from eofs.iris import Eof

from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE

# %%
data = pd.read_csv('/Volumes/Database/Research/ozone-budget/result_df_UKESM1_3_0_NN_width_64_dropout_0.1_90.csv')
data
# Out:
#                  HO₂         CH₃O₂         kₓROₓ           O¹D     kₐalkenes  \
# 0       7.280630e-12  4.660699e-11  2.658377e-28  9.069226e-22  3.638301e-28
# 1       7.281262e-12  4.661300e-11  2.658434e-28  9.071393e-22  3.638602e-28
# 2       7.261796e-12  4.650557e-11  2.651481e-28  9.122343e-22  3.619068e-28
# 3       7.261786e-12  4.651602e-11  2.652178e-28  9.121947e-22  3.614559e-28
# 4       7.261663e-12  4.652939e-11  2.652065e-28  9.120833e-22  3.616232e-28
# ...              ...           ...           ...           ...           ...
# 971995  1.387260e-14  8.797916e-14  2.047809e-31  7.619175e-25  8.489538e-31
# 971996  1.259138e-14  8.829640e-14  1.989219e-31  9.184654e-25  1.161733e-30
# 971997  1.375304e-14  9.701694e-14  2.127389e-31  9.824132e-25  1.220742e-30
# 971998  1.362856e-14  9.592115e-14  2.115101e-31  9.784521e-25  1.211627e-30
# 971999  9.642946e-15  6.869784e-14  1.565586e-31  9.185482e-25  1.328074e-30
#
# ...

# %%
list(data)
# Out:
# ['HO₂',
#  'CH₃O₂',
#  'kₓROₓ',
#  'O¹D',
#  'kₐalkenes',
#  'PO₃̂',
#  'LO₃̂',
#  'longitude',
#  'latitude',
#  't',
#  'o3',
#  'no2',
#  'no',
#  'oh',
#  'h2o',
#  'hno3',
#  'o3prod',
#  'o3loss',
#  'k_no_ho2',
#  'k_no_ch3o2',
#  'k_o1d_h2o',
#  'k_o3_oh',
#  'k_o3_ho2']

# %%
R2(data['PO₃̂'], data['o3prod']*0.5552*10**18)
# Out:
# 0.9385804401391507

# %%
data['loc'] = data['longitude']*1000+data['latitude']
data_map = data.groupby(['loc']).mean()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(20, 8.24), dpi=100, facecolor='w', edgecolor='k')

plt.subplot(2,3,1)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['oh']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)

plt.subplot(2,3,2)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['HO₂']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)

plt.subplot(2,3,3)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['CH₃O₂']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)

plt.subplot(2,3,4)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['kₓROₓ']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)

plt.subplot(2,3,5)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['O¹D']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)

plt.subplot(2,3,6)
cm = plt.cm.get_cmap('Blues')
x = data_map['longitude']
y = data_map['latitude']
z = data_map['kₐalkenes']
sc = plt.scatter(x, y, c=z, marker="s", s=25, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.colorbar(sc)
